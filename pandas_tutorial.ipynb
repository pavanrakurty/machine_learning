# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanrakurty/machine_learning/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Creating Pandas dataframe

# %%
#importing boston data
from sklearn.datasets import load_diabetes

# %%
diabetes_dataset = load_diabetes()

# %%
print(diabetes_dataset)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
diab_df = pd.DataFrame(data=diabetes_dataset.data, columns=diabetes_dataset.feature_names)

# %%
diab_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
diab_df.shape
# Out:
# (442, 10)

# %% [markdown]
# Importing data from csv into pandas dataframe

# %%
diab_df2 = pd.read_csv('/content/sample_data/diabetes.csv')

# %%
diab_df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diab_df2.shape
# Out:
# (768, 9)

# %% [markdown]
# Exporting dataframe to csv

# %%
diab_df.to_csv('test_export.csv')

# %%
import numpy as np

# %%
random_df = pd.DataFrame(data=np.random.rand(20, 10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.662504  0.823473  0.401976  0.934669  0.934298  0.662927  0.782640
# 1  0.488601  0.016992  0.483913  0.371822  0.452340  0.112457  0.160203
# 2  0.242723  0.820900  0.882443  0.453783  0.885143  0.320152  0.803130
# 3  0.540355  0.763036  0.154380  0.904582  0.101216  0.812321  0.315377
# 4  0.266735  0.230859  0.372970  0.956181  0.319440  0.329840  0.536828
#
#           7         8         9
# 0  0.954847  0.687294  0.453182
# 1  0.933730  0.060854  0.209773
# 2  0.212947  0.838946  0.068744
# 3  0.180687  0.029511  0.834159
# 4  0.240417  0.345045  0.096126

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a dataframe

# %%
diab_df.shape
# Out:
# (442, 10)

# %%
diab_df.head()
diab_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
diab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
diab_df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting values based on label
diab_df2.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#group values based on mean
diab_df2.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical measures on dataset

# %%
#count number of values
diab_df2.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#mean of values
diab_df2.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#standard deivation
diab_df2.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#min value in each col
diab_df2.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#max value in each col
diab_df2.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
#all statistical measures of df
diab_df2.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Manipulating dataframe

# %%
#adding column to dataframe
diab_df['target'] = diabetes_dataset.target
diab_df.head()

##number of rows should be same while adding
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
#removing a row
diab_df = diab_df.drop(index = 0, axis = 0)
diab_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
#
#          s4        s5        s6  target
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0
# 5 -0.076395 -0.041176 -0.096346    97.0

# %%
#drop a column
diab_df = diab_df.drop(columns = 'bp', axis = 1)
diab_df.head()
# Out:
#         age       sex       bmi        s1        s2        s3        s4  \
# 1 -0.001882 -0.044642 -0.051474 -0.008449 -0.019163  0.074412 -0.039493
# 2  0.085299  0.050680  0.044451 -0.045599 -0.034194 -0.032356 -0.002592
# 3 -0.089063 -0.044642 -0.011595  0.012191  0.024991 -0.036038  0.034309
# 4  0.005383 -0.044642 -0.036385  0.003935  0.015596  0.008142 -0.002592
# 5 -0.092695 -0.044642 -0.040696 -0.068991 -0.079288  0.041277 -0.076395
#
#          s5        s6  target
# 1 -0.068332 -0.092204    75.0
# 2  0.002861 -0.025930   141.0
# 3  0.022688 -0.009362   206.0
# 4 -0.031988 -0.046641   135.0
# 5 -0.041176 -0.096346    97.0

# %%
#locating a row using index value
diab_df.iloc[2]
# Out:
# age        -0.089063
# sex        -0.044642
# bmi        -0.011595
# s1          0.012191
# s2          0.024991
# s3         -0.036038
# s4          0.034309
# s5          0.022688
# s6         -0.009362
# target    206.000000
# Name: 3, dtype: float64

# %%
#locating a particular column
print(diab_df.iloc[:,0]) #first column
print(diab_df.iloc[:,-1]) #last column
print(diab_df.iloc[:,1]) #second column
# Out:
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
# 5     -0.092695
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 441, dtype: float64
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
# 5       97.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 441, dtype: float64
# 1     -0.044642
# 2      0.050680
# 3     -0.044642
# 4     -0.044642
# 5     -0.044642
#          ...
# 437    0.050680
# 438    0.050680
# 439    0.050680
# 440   -0.044642
# 441   -0.044642
# Name: sex, Length: 441, dtype: float64

# %% [markdown]
# Correlation(Positive / Negative correlation)

# %%
diab_df.corr()
# Out:
#              age       sex       bmi        s1        s2        s3        s4  \
# age     1.000000  0.172150  0.183213  0.262196  0.220867 -0.073648  0.204089
# sex     0.172150  1.000000  0.085300  0.037608  0.144680 -0.377728  0.332676
# bmi     0.183213  0.085300  1.000000  0.253243  0.263987 -0.365169  0.414760
# s1      0.262196  0.037608  0.253243  1.000000  0.896543  0.049691  0.542626
# s2      0.220867  0.144680  0.263987  0.896543  1.000000 -0.198277  0.660130
# s3     -0.073648 -0.377728 -0.365169  0.049691 -0.198277  1.000000 -0.739306
# s4      0.204089  0.332676  0.414760  0.542626  0.660130 -0.739306  1.000000
# s5      0.270265  0.149127  0.445865  0.516995  0.319309 -0.398166  0.618036
# s6      0.302672  0.209332  0.390578  0.325304  0.290206 -0.274767  0.417233
# target  0.188052  0.043153  0.587616  0.212200  0.174135 -0.395193  0.430453
#
#               s5        s6    target
# age     0.270265  0.302672  0.188052
# sex     0.149127  0.209332  0.043153
# ...
